# %%
import pandas as pd
#df1 = pd.read_csv('https://app.periscopedata.com/api/creditninja/chart/csv/9521e869-b643-fac6-8679-e7340cf5ed7e')

df1_head = df1[0:100]
df1_tail = df1[100:len(df1)]

from sqlalchemy import create_engine
engine = create_engine('postgresql://'
                      + 'sagemaker' + ':' 
                      + '986Sz3V*0t90t'  + '@'
                      + "creditninja.periscopewarehouse.com" + ':'
                      + '5439' + '/' 
                      + 'site_14596', echo=False)

#df1_head.to_sql(name='service_objects_features', schema='analytics', con=engine, if_exists = 'replace', index=False)

# %%
#df1 = pd.read_csv('https://app.periscopedata.com/api/creditninja/chart/csv/9521e869-b643-fac6-8679-e7340cf5ed7e')
df1 = df1.where((pd.notnull(df1)), None)

# %%
print(df1.shape)
df1.head()
# Out:
# (10000, 78)
#    len_of_name_in_leads  len_of_address_in_leads m_provider_name  \
# 0                    16                       20          SPRINT
# 1                    12                       37         VERIZON
# 2                    10                       15          AERIAL
# 3                    17                       26          SPRINT
# 4                    14                       18          SPRINT
#
#   w_provider_name h_provider_name m_zip_haversine_distance  \
# 0           OTHER          SPRINT                     None
# 1           OTHER         VERIZON                     None
# 2           OTHER          AERIAL                  134.937
# 3           OTHER          SPRINT                        0
# 4           OTHER          AERIAL                        0
#
#   w_zip_haversine_distance h_zip_haversine_distance m_w_area_match  \
# 0                  10.5607                     None              1
# 1                  1595.96                     None              0
# 2                     None                  134.937              0
# 3                        0                        0              1
# 4                        0                        0              1
#
#   m_h_area_match                 ...                  h_is_portable_voip  \
# 0              1                 ...                                   0
# 1              1                 ...                                   0
# 2              1                 ...                                   0
# 3              1                 ...                                   0
# 4              1                 ...                                   0
#
#   h_is_possible_portable_voip h_is_contact_address_po_box  \
# 0                           0                        None
# 1                           0                        None
# 2                           0                        None
# 3                           0                           0
# 4                           0                           0
#
#   h_contact_address_match_lev8 h_cont_addr_lev_dist  h_cont_addr_len  \
# 0                         None                 None             None
# 1                         None                 None             None
# 2                         None                 None             None
# 3                            1                    2               24
# 4                            1                    0               18
#
#    h_cont_addr_lev_dist_ratio  h_contact_quality_score  h_contact_phone_type  \
# 0                        None                     None                  None
# 1                        None                     None                  None
# 2                        None                      MED           RESIDENTIAL
# 3                   0.0769231                     HIGH           RESIDENTIAL
# 4                           0                      LOW           RESIDENTIAL
#
#    h_days_of_porting_since_in_infinity
# 0                                 None
# 1                                -4055
# 2                                 -404
# 3                                 -678
# 4                                 None
#
# [5 rows x 78 columns]

# %%
tuples = [tuple(x) for x in df1.values]
connection = engine.raw_connection()
cur = connection.cursor()

args_str = b",".join(cur.mogrify("%s", (x, )) for x in tuples)
args_str_str=args_str.decode()

insert_str = "insert into analytics.service_objects_features(" 
for var in df1:
    insert_str += var
    #insert_str += ('\"' + var + '\"') 
    insert_str += ','
insert_str = insert_str[:-1]
insert_str += ') values '
insert_str += args_str_str

cur.execute('rollback')
cur.execute('begin')
#cur.execute("alter table analytics.zip_code_mapping alter column \"WorldRegion\" type text;")
cur.execute(insert_str)
cur.execute('commit')

# %%
#df2=pd.read_csv('https://app.periscopedata.com/api/creditninja/chart/csv/740bf883-455e-5375-770c-4968bfed7dfc')
#df2 = df2.where((pd.notnull(df2)), None)
print(df2.shape)
df2.head()
# Out:
# (10000, 78)
#    len_of_name_in_leads  len_of_address_in_leads m_provider_name  \
# 0                    14                       12        T-MOBILE
# 1                    14                       15        CINGULAR
# 2                    16                       20       METRO_PCS
# 3                    11                       26       METRO_PCS
# 4                    11                       20            AT&T
#
#   w_provider_name h_provider_name m_zip_haversine_distance  \
# 0           OTHER        T-MOBILE                     None
# 1           OTHER           OTHER                  2284.87
# 2           OTHER           OTHER                        0
# 3           OTHER       METRO_PCS                     None
# 4        CINGULAR            AT&T                        0
#
#   w_zip_haversine_distance h_zip_haversine_distance  m_w_area_match  \
# 0                  2.15157                     None               1
# 1                  5.98754                     None               0
# 2                  14.2499                     None               1
# 3                  331.932                     None               0
# 4                  23.7807                        0               0
#
#   m_h_area_match                 ...                  h_is_portable_voip  \
# 0              1                 ...                                   0
# 1           None                 ...                                   0
# 2           None                 ...                                   0
# 3              1                 ...                                   0
# 4              1                 ...                                   0
#
#   h_is_possible_portable_voip  h_is_contact_address_po_box  \
# 0                           0                         None
# 1                           0                         None
# 2                           0                         None
# 3                           0                         None
# 4                           0                            0
#
#    h_contact_address_match_lev8 h_cont_addr_lev_dist  h_cont_addr_len  \
# 0                          None                 None             None
# 1                          None                 None             None
# 2                          None                 None             None
# 3                          None                 None             None
# 4                             1                    4               16
#
#    h_cont_addr_lev_dist_ratio  h_contact_quality_score  h_contact_phone_type  \
# 0                        None                      MED           RESIDENTIAL
# 1                        None                     None                  None
# 2                        None                     None                  None
# 3                        None                     None                  None
# 4                         0.2                     HIGH           RESIDENTIAL
#
#    h_days_of_porting_since_in_infinity
# 0                                -1203
# 1                                 None
# 2                                 None
# 3                                 -367
# 4                                -3387
#
# [5 rows x 78 columns]

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://'
                      + 'sagemaker' + ':' 
                      + '986Sz3V*0t90t'  + '@'
                      + "creditninja.periscopewarehouse.com" + ':'
                      + '5439' + '/' 
                      + 'site_14596', echo=False)

tuples = [tuple(x) for x in df2.values]
connection = engine.raw_connection()
cur = connection.cursor()

args_str = b",".join(cur.mogrify("%s", (x, )) for x in tuples)
args_str_str=args_str.decode()

insert_str = "insert into analytics.service_objects_features(" 
for var in df2:
    insert_str += var
    #insert_str += ('\"' + var + '\"') 
    insert_str += ','
insert_str = insert_str[:-1]
insert_str += ') values '
insert_str += args_str_str

cur.execute('rollback')
cur.execute('begin')
#cur.execute("alter table analytics.zip_code_mapping alter column \"WorldRegion\" type text;")
cur.execute(insert_str)
cur.execute('commit')

# %%
df3 = pd.read_csv('https://app.periscopedata.com/api/creditninja/chart/csv/7114ec1f-2673-a840-1722-9e9f5dc8cbd5')
df3 = df3.where((pd.notnull(df3)), None)
print(df3.shape)
df3.head()
# Out:
# (10000, 78)
#    len_of_name_in_leads  len_of_address_in_leads m_provider_name  \
# 0                    12                       20          SPRINT
# 1                    13                       13         VERIZON
# 2                    10                       13        POWERTEL
# 3                    15                       15        CINGULAR
# 4                    15                       15         VERIZON
#
#   w_provider_name h_provider_name m_zip_haversine_distance  \
# 0           OTHER           OTHER                  12.6579
# 1         VERIZON           OTHER                        0
# 2           OTHER           OTHER                  1813.16
# 3        CINGULAR           OTHER                        0
# 4           OTHER           OTHER                     None
#
#   w_zip_haversine_distance h_zip_haversine_distance  m_w_area_match  \
# 0                        0                     None               1
# 1                        0                     None               1
# 2                  27.4536                     None               0
# 3                  13.8265                     None               1
# 4                   4.8737                     None               1
#
#   m_h_area_match                 ...                  h_is_portable_voip  \
# 0           None                 ...                                   0
# 1           None                 ...                                   0
# 2           None                 ...                                   0
# 3           None                 ...                                   0
# 4           None                 ...                                   0
#
#   h_is_possible_portable_voip  h_is_contact_address_po_box  \
# 0                           0                         None
# 1                           0                         None
# 2                           0                         None
# 3                           0                         None
# 4                           0                         None
#
#    h_contact_address_match_lev8 h_cont_addr_lev_dist  h_cont_addr_len  \
# 0                          None                 None             None
# 1                          None                 None             None
# 2                          None                 None             None
# 3                          None                 None             None
# 4                          None                 None             None
#
#    h_cont_addr_lev_dist_ratio  h_contact_quality_score  h_contact_phone_type  \
# 0                        None                     None                  None
# 1                        None                     None                  None
# 2                        None                     None                  None
# 3                        None                     None                  None
# 4                        None                     None                  None
#
#    h_days_of_porting_since_in_infinity
# 0                                 None
# 1                                 None
# 2                                 None
# 3                                 None
# 4                                 None
#
# [5 rows x 78 columns]

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://'
                      + 'sagemaker' + ':' 
                      + '986Sz3V*0t90t'  + '@'
                      + "creditninja.periscopewarehouse.com" + ':'
                      + '5439' + '/' 
                      + 'site_14596', echo=False)

tuples = [tuple(x) for x in df3.values]
connection = engine.raw_connection()
cur = connection.cursor()

args_str = b",".join(cur.mogrify("%s", (x, )) for x in tuples)
args_str_str=args_str.decode()

insert_str = "insert into analytics.service_objects_features(" 
for var in df3:
    insert_str += var
    #insert_str += ('\"' + var + '\"') 
    insert_str += ','
insert_str = insert_str[:-1]
insert_str += ') values '
insert_str += args_str_str

cur.execute('rollback')
cur.execute('begin')
#cur.execute("alter table analytics.zip_code_mapping alter column \"WorldRegion\" type text;")
cur.execute(insert_str)
cur.execute('commit')

# %%
import pandas as pd
df4 = pd.read_csv('https://app.periscopedata.com/api/creditninja/chart/csv/e233b541-dee0-ed27-46a8-9710acaa8112')
df4 = df4.where((pd.notnull(df4)), None)
print(df4.shape)
df4.head()
# Out:
# (10000, 78)
#    len_of_name_in_leads  len_of_address_in_leads m_provider_name  \
# 0                    15                       13        T-MOBILE
# 1                    10                       17        CINGULAR
# 2                    15                       15           OTHER
# 3                    13                       17        T-MOBILE
# 4                    11                       19        T-MOBILE
#
#   w_provider_name h_provider_name m_zip_haversine_distance  \
# 0           OTHER           OTHER                   9.6955
# 1           OTHER           OTHER                  9.37114
# 2           OTHER           OTHER                   8.2959
# 3        T-MOBILE           OTHER                     None
# 4           OTHER           OTHER                  7.42696
#
#   w_zip_haversine_distance h_zip_haversine_distance  m_w_area_match  \
# 0                  11.0628                     None               0
# 1                     None                     None               0
# 2                     None                     None               0
# 3                     None                     None               1
# 4                  1731.45                     None               0
#
#   m_h_area_match                 ...                  h_is_portable_voip  \
# 0           None                 ...                                   0
# 1           None                 ...                                   0
# 2           None                 ...                                   0
# 3           None                 ...                                   0
# 4           None                 ...                                   0
#
#   h_is_possible_portable_voip  h_is_contact_address_po_box  \
# 0                           0                         None
# 1                           0                         None
# 2                           0                         None
# 3                           0                         None
# 4                           0                         None
#
#    h_contact_address_match_lev8 h_cont_addr_lev_dist  h_cont_addr_len  \
# 0                          None                 None             None
# 1                          None                 None             None
# 2                          None                 None             None
# 3                          None                 None             None
# 4                          None                 None             None
#
#    h_cont_addr_lev_dist_ratio  h_contact_quality_score  h_contact_phone_type  \
# 0                        None                     None                  None
# 1                        None                     None                  None
# 2                        None                     None                  None
# 3                        None                     None                  None
# 4                        None                     None                  None
#
#    h_days_of_porting_since_in_infinity
# 0                                 None
# 1                                 None
# 2                                 None
# 3                                 None
# 4                                 None
#
# [5 rows x 78 columns]

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://'
                      + 'sagemaker' + ':' 
                      + '986Sz3V*0t90t'  + '@'
                      + "creditninja.periscopewarehouse.com" + ':'
                      + '5439' + '/' 
                      + 'site_14596', echo=False)

tuples = [tuple(x) for x in df4.values]
connection = engine.raw_connection()
cur = connection.cursor()


args_str = b",".join(cur.mogrify("%s", (x, )) for x in tuples)
args_str_str=args_str.decode()


insert_str = "insert into analytics.service_objects_features(" 
for var in df4:
    insert_str += var
    #insert_str += ('\"' + var + '\"') 
    insert_str += ','
insert_str = insert_str[:-1]
insert_str += ') values '
insert_str += args_str_str


cur.execute('rollback')
cur.execute('begin')
#cur.execute("alter table analytics.zip_code_mapping alter column \"WorldRegion\" type text;")
cur.execute(insert_str)
cur.execute('commit')

# %%
df5 = pd.read_csv('https://app.periscopedata.com/api/creditninja/chart/csv/952f02a7-83d7-c5cb-4a67-7a4546e14b99') 
df5 = df5.where((pd.notnull(df5)), None)
print(df5.shape)
df5.head()
# Out:
# (7033, 78)
#    len_of_name_in_leads  len_of_address_in_leads m_provider_name  \
# 0                    12                       21         VERIZON
# 1                    14                       14         VERIZON
# 2                    13                       12         VERIZON
# 3                    11                       21        CINGULAR
# 4                    10                        9          SPRINT
#
#   w_provider_name h_provider_name m_zip_haversine_distance  \
# 0           OTHER         VERIZON                        0
# 1           OTHER         VERIZON                     None
# 2           OTHER         VERIZON                     None
# 3           OTHER        CINGULAR                        0
# 4           OTHER          SPRINT                        0
#
#   w_zip_haversine_distance h_zip_haversine_distance  m_w_area_match  \
# 0                  5.28159                        0               0
# 1                        0                     None               1
# 2                  45.5203                     None               1
# 3                        0                        0               1
# 4                        0                        0               1
#
#   m_h_area_match                 ...                  h_is_portable_voip  \
# 0              1                 ...                                   0
# 1              1                 ...                                   0
# 2              1                 ...                                   0
# 3              1                 ...                                   0
# 4              1                 ...                                   0
#
#   h_is_possible_portable_voip  h_is_contact_address_po_box  \
# 0                           0                            0
# 1                           0                         None
# 2                           0                         None
# 3                           0                         None
# 4                           0                            0
#
#    h_contact_address_match_lev8 h_cont_addr_lev_dist  h_cont_addr_len  \
# 0                             1                    3               18
# 1                          None                 None             None
# 2                          None                 None             None
# 3                          None                 None             None
# 4                             1                    3               12
#
#    h_cont_addr_lev_dist_ratio  h_contact_quality_score  h_contact_phone_type  \
# 0                    0.142857                      LOW           RESIDENTIAL
# 1                        None                     None                  None
# 2                        None                     None                  None
# 3                        None                      MED           RESIDENTIAL
# 4                        0.25                      LOW           RESIDENTIAL
#
#    h_days_of_porting_since_in_infinity
# 0                                 None
# 1                                 None
# 2                                 None
# 3                                 None
# 4                                -3743
#
# [5 rows x 78 columns]

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://'
                      + 'sagemaker' + ':' 
                      + '986Sz3V*0t90t'  + '@'
                      + "creditninja.periscopewarehouse.com" + ':'
                      + '5439' + '/' 
                      + 'site_14596', echo=False)

tuples = [tuple(x) for x in df5.values]
connection = engine.raw_connection()
cur = connection.cursor()

args_str = b",".join(cur.mogrify("%s", (x, )) for x in tuples)
args_str_str=args_str.decode()

insert_str = "insert into analytics.service_objects_features(" 
for var in df5:
    insert_str += var
    #insert_str += ('\"' + var + '\"') 
    insert_str += ','
insert_str = insert_str[:-1]
insert_str += ') values '
insert_str += args_str_str

cur.execute('rollback')
cur.execute('begin')
#cur.execute("alter table analytics.zip_code_mapping alter column \"WorldRegion\" type text;")
cur.execute(insert_str)
cur.execute('commit')
